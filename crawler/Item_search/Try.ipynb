# %%
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import re, requests, json, time

def getHtml(method, url, params= None, data= None, encoding= 'utf-8'):
    try:
        headers = {'user-agent':str(UserAgent().random)}
        if method == 'get':
            req = requests.get(url, headers= headers, params= params)
        elif method == 'post':
            req = requests.post(url, headers= headers, data= data)
        if req.status_code == 200:
            print('requests -> 200')
            req.encoding = encoding
            return BeautifulSoup(req.text, 'html.parser')
        print('requests -> ', req.status_code)
        return None
    except:
        return None
def textClean(splitChar='', text='', loop=1, reRight=True, notReverse = True): #
    myIndex = 1 if notReverse else 0
    myLoop = 0
    myRange = text if notReverse else reversed(text)
    for i in myRange:
        if i == splitChar: 
            myLoop+=1
            if myLoop==loop: 
                if reRight:
                    return text[myIndex:] if notReverse else text[-myIndex:] # 由index至右
                return text[:myIndex] if notReverse else text[:-myIndex] # 由左至index
        myIndex+=1

# %%
soup = getHtml(url = "https://search.books.com.tw/search/query/key/python/cat/all", method="get")
# Out:
# requests -> 200

# %%
item_soup = soup.find('ul', class_='searchbook').findAll('li', class_="item")

# %%
item_indexs = []
pattern = re.compile("[0-9]*")
for i in item_soup:
    value = i.find('input', {'name':'C2'})
    if value!=None:
        item_indexs.append(value['value'])
    else:
        try:
            href = i.find('a', {'rel':'mid_image'})['href']
            value = re.split('item/|/page',href)[1]
            if pattern.fullmatch(value)!=None:
                item_indexs.append(value['value'])
            else:
                item_indexs.append(None)
        except:
            print('取得item index錯誤...')
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
pattern = re.compile("[0-9]*")
print(pattern.fullmatch(q))
# Out:
# <re.Match object; span=(0, 10), match='0010861459'>

# %%
with open('items1123.json', 'w', encoding='utf-8') as fp:
    fp.write(json.dumps({
        "status": True,
        "info": [
            {
                "exist": {
                    "books": True,
                    "sanmin": None,
                    "kingstorn": None,
                    "eslite": None
                },
                "index": "0010869590",
                "imgURL": None,
                "title": "Python最強入門邁向頂尖高手之路：王者歸來(第二版)全彩版",
                "price": "853",
                "date": "2020/09/17",
                "author": "洪錦魁",
                "pub": "深智數位"
            },
            {
                "exist": {},
                "index": "0010858475",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/085/84/0010858475.jpg",
                "title": "精通 Python：運用簡單的套件進行現代運算(第二版)",
                "price": "695",
                "date": "2020-06-02",
                "author": "Bill Lubanovic, 賴屹民",
                "pub": "歐萊禮"
            },
            {
                "exist": {},
                "index": "0010863623",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/086/36/0010863623.jpg",
                "title": "Python初學特訓班(第四版)：從快速入門到主流應用全面實戰(附250分鐘影音教學/範例程式)",
                "price": "379",
                "date": "2020-07-15",
                "author": "文淵閣工作室",
                "pub": "碁峰"
            },
            {
                "exist": {
                    "books": True,
                    "sanmin": None,
                    "kingstorn": True,
                    "eslite": True
                },
                "index": "0010867440",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/086/74/0010867440.jpg",
                "title": "Python 自動化的樂趣：搞定重複瑣碎&單調無聊的工作(第二版)",
                "price": "537",
                "date": "2020-08-28",
                "author": "Al Sweigart, H&C",
                "pub": "碁峰"
            },
            {
                "exist": {},
                "index": "0010870722",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/07/0010870722.jpg",
                "title": "Python機器學習超進化：AI影像辨識跨界應用實戰(附100分鐘影像處理入門影音教學/範例程式)",
                "price": "356",
                "date": "2020-09-22",
                "author": "文淵閣工作室, 鄧文淵",
                "pub": "碁峰"
            },
            {
                "exist": {},
                "index": "0010872935",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/29/0010872935.jpg",
                "title": "Python 從初學到生活應用超實務：讓 Python 幫你處理日常生活與工作中繁瑣重複的工作",
                "price": "490",
                "date": "2020-10-16",
                "author": "陳會安",
                "pub": "博碩"
            },
            {
                "exist": {},
                "index": "0010859289",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/085/92/0010859289.jpg",
                "title": "Python大數據特訓班(第二版)：資料自動化收集、整理、清洗、儲存、分析與應用實戰(附300分鐘影音教學/範例程式)",
                "price": "411",
                "date": "2020-06-01",
                "author": "文淵閣工作室, 鄧文淵",
                "pub": "碁峰"
            },
            {
                "exist": {},
                "index": "0010874725",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/47/0010874725.jpg",
                "title": "Python零基礎學程式設計與運算思維：王者歸來 (第二版)",
                "price": "537",
                "date": "2020-11-10",
                "author": "洪錦魁",
                "pub": "深智數位"
            },
            {
                "exist": {
                    "books": True,
                    "sanmin": True,
                    "kingstorn": True,
                    "eslite": True
                },
                "index": "0010873248",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/32/0010873248.jpg",
                "title": "Python for DevOps|學習精準有效的自動化",
                "price": "702",
                "date": "2020-10-19",
                "author": "Alfredo Deza, Grig Gheorghiu, Kennedy Behrman, Noah Gift, 盧建成",
                "pub": "歐萊禮"
            },
            {
                "exist": {},
                "index": "0010851019",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/085/10/0010851019.jpg",
                "title": "Python自學聖經：從程式素人到開發強者的技術與實戰大全!(附影音/範例程式)",
                "price": "695",
                "date": "2020-03-11",
                "author": "文淵閣工作室, 鄧文淵",
                "pub": "碁峰"
            },
            {
                "exist": {},
                "index": "0010871074",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/10/0010871074.jpg",
                "title": "使用Python搜刮網路資料的12堂實習課",
                "price": "411",
                "date": "2020-09-30",
                "author": "何敏煌, 葉柏漢, 顏凰竹",
                "pub": "博碩"
            },
            {
                "exist": {},
                "index": "0010866777",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/086/67/0010866777.jpg",
                "title": "機器學習：彩色圖解 + 基礎數學篇 + Python實作 王者歸來(全彩)",
                "price": "435",
                "date": "2020-08-17",
                "author": "洪錦魁",
                "pub": "深智數位"
            },
            {
                "exist": {},
                "index": "0010871454",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/14/0010871454.jpg",
                "title": "Python機器學習第三版(下)",
                "price": "411",
                "date": "2020-10-06",
                "author": "Sebastian Raschka, Vahid Mirjalili, 劉立民, 吳建華",
                "pub": "博碩"
            },
            {
                "exist": {},
                "index": "0010869555",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/086/95/0010869555.jpg",
                "title": "Python機器學習第三版(上)",
                "price": "490",
                "date": "2020-09-14",
                "author": "Sebastian Raschka, Vahid Mirjalili, 劉立民, 吳建華",
                "pub": "博碩"
            },
            {
                "exist": {},
                "index": "0010869464",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/086/94/0010869464.jpg",
                "title": "Python程式交易應用與實作：從零開始!自動化投資實戰指南",
                "price": "395",
                "date": "2020-09-10",
                "author": "劉承彥, 酆士昌",
                "pub": "博碩"
            },
            {
                "exist": {},
                "index": "0010852573",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/085/25/0010852573.jpg",
                "title": "演算法：最強彩色圖鑑 + Python程式實作 王者歸來(全彩印刷)",
                "price": "537",
                "date": "2020-04-02",
                "author": "洪錦魁",
                "pub": "深智數位"
            },
            {
                "exist": {},
                "index": "0010857799",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/085/77/0010857799.jpg",
                "title": "深度學習的數學地圖：用 Python 實作神經網路的數學模型(附數學快查學習地圖)",
                "price": "458",
                "date": "2020-05-28",
                "author": "Masanori Akaishi, 王心薇, 章奇煒",
                "pub": "旗標"
            },
            {
                "exist": {},
                "index": "0010836667",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/083/66/0010836667.jpg",
                "title": "Python網路爬蟲：大數據擷取、清洗、儲存與分析：王者歸來",
                "price": "514",
                "date": "2019-10-20",
                "author": "洪錦魁",
                "pub": "深智數位"
            },
            {
                "exist": {},
                "index": "0010870147",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/01/0010870147.jpg",
                "title": "Python資料可視化之美：極專業圖表製作高手書(全彩印刷)",
                "price": "616",
                "date": "2020-09-21",
                "author": "張傑",
                "pub": "深智數位"
            },
            {
                "exist": {},
                "index": "0010861459",
                "imgURL": "https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/086/14/0010861459.jpg",
                "title": "決心打底!Python 深度學習基礎養成",
                "price": "545",
                "date": "2020-07-07",
                "author": "我妻幸長, 吳嘉芳",
                "pub": "旗標"
            }
        ]
}))
